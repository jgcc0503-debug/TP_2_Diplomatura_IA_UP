# %%
import pandas as pd

# %% [markdown]
# Se importa Dataset de entrenamiento y el de simulación

# %%
drive.mount('/content/drive')

ruta_train = '/content/drive/My Drive/Training_And_Testing_Dataset/smoking_prediction.csv'
ruta_test = '/content/drive/My Drive/Training_And_Testing_Dataset/smoking_prediction_entrega.csv'
df_train = pd.read_csv(ruta_train)
df_test = pd.read_csv(ruta_test)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Se revista estado de dataset de entrenamiento, identificando la columna "Smoking" que contiene las etiquetas binarias que se utilizaran para entrenar los modelos.
# Tambien se verifica la cantidad de datos por variables y su tipo, sin nulos.

# %%
print("--- DATASET DE ENTRENAMIENTO ---")
print(f"Dimensiones: {df_train.shape[0]} filas y {df_train.shape[1]} columnas.")
print("\nInformación general de las columnas:")
df_train.info()
# Out:
# --- DATASET DE ENTRENAMIENTO ---
# Dimensiones: 50000 filas y 27 columnas.
#
# Información general de las columnas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   gender               50000 non-null  object
#  2   age                  50000 non-null  int64
#  3   height(cm)           50000 non-null  int64
#  4   weight(kg)           50000 non-null  int64
#  5   waist(cm)            50000 non-null  float64
#  6   eyesight(left)       50000 non-null  float64
#  7   eyesight(right)      50000 non-null  float64
#  8   hearing(left)        50000 non-null  float64
#  9   hearing(right)       50000 non-null  float64
#  10  systolic             50000 non-null  float64
#  11  relaxation           50000 non-null  float64
#  12  fasting blood sugar  50000 non-null  float64
# ...

# %% [markdown]
# Se verifica que el dataset de simulación es carente de la columna de sesgo binario, de menor volumen de datos, conteniendo las mismas variables principales que el dataset de entrenamiento, sin nulos.

# %%
print("--- DATASET DE SIMULACIÓN ---")
print(f"Dimensiones: {df_test.shape[0]} filas y {df_test.shape[1]} columnas.")
print("\nInformación general de las columnas:")
df_test.info()
# Out:
# --- DATASET DE SIMULACIÓN ---
# Dimensiones: 5692 filas y 26 columnas.
#
# Información general de las columnas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5692 entries, 0 to 5691
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5692 non-null   int64
#  1   gender               5692 non-null   object
#  2   age                  5692 non-null   int64
#  3   height(cm)           5692 non-null   int64
#  4   weight(kg)           5692 non-null   int64
#  5   waist(cm)            5692 non-null   float64
#  6   eyesight(left)       5692 non-null   float64
#  7   eyesight(right)      5692 non-null   float64
#  8   hearing(left)        5692 non-null   float64
#  9   hearing(right)       5692 non-null   float64
#  10  systolic             5692 non-null   float64
#  11  relaxation           5692 non-null   float64
#  12  fasting blood sugar  5692 non-null   float64
# ...

# %% [markdown]
# Se observan las columnas y las primeras filas de los datasets

# %%
display(df_train.head())
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       3.38            0.04
# 1   1      F   40         160          60       3.38            0.01
# 2   2      M   55         170          60       3.33            0.01
# 3   3      M   40         165          70       3.67            0.05
# 4   4      F   40         155          60       3.58            0.04
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0             0.04           0.04            0.04  ...        0.51
# 1             0.00           0.04            0.04  ...        0.50
# 2             0.01           0.04            0.04  ...        0.63
# 3             0.05           0.04            0.04  ...        0.59
# 4             0.04           0.04            0.04  ...        0.50
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...

# %%
display(df_test.head())
# Out:
#       ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0  27358      M   25         160          65       3.42            0.05
# 1  27364      M   30         180          80       3.46            0.04
# 2  27368      M   55         165          60       3.42            0.00
# 3  27378      M   20         175          75       3.63            0.05
# 4  27381      M   25         165          80       3.79            0.04
#
#    eyesight(right)  hearing(left)  hearing(right)  ...   LDL  hemoglobin  \
# 0             0.00           0.04            0.04  ...  3.04        0.63
# 1             0.01           0.04            0.04  ...  4.21        0.59
# 2             0.01           0.04            0.04  ...  2.04        0.63
# 3             0.05           0.04            0.04  ...  3.71        0.63
# 4             0.04           0.04            0.04  ...  6.63        0.67
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...
